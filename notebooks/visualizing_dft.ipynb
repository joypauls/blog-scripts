# %%
import numpy as np
import matplotlib.pyplot as plt

n = 256
w = np.exp(-1j * 2 * np.pi / n)
J,K = np.meshgrid(np.arange(n), np.arange(n))
DFT = np.power(w, J * K)
DFT = np.real(DFT)


# plt.style.use("seaborn-v0_8-whitegrid")
plt.figure(figsize=(6, 6))
plt.matshow(DFT, cmap="plasma", fignum=1)
plt.title("DFT matrix")
# plt.axis("off")
# plt.colorbar()
plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# n = 256
# w = np.exp(-1j * 2 * np.pi / n)
# J,K = np.meshgrid(np.arange(n), np.arange(n))
# DFT = np.power(w, J * K)
# DFT = np.real(DFT)

# plot_dft_real_matrix(n):
#     w = np.exp(-1j * 2 * np.pi / n)
#     J,K = np.meshgrid(np.arange(n), np.arange(n))
#     DFT = np.power(w, J * K)
#     DFT = np.real(DFT)
#     return plt.matshow(DFT, cmap="plasma", fignum=1)


# # plt.style.use("seaborn-v0_8-whitegrid")
# plt.figure(figsize=(6, 6))
# plt.matshow(DFT, cmap="plasma", fignum=1)
# plt.title("DFT matrix")
# # plt.axis("off")
# # plt.colorbar()
# plt.show()
