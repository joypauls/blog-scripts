# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gray = cv2.cvtColor(cv2.imread("../data/heron_grayscale.jpg"), cv2.COLOR_BGR2GRAY)
color = cv2.imread("../data/heron_color.jpg")


print(gray.shape)
print(color.shape)
# Out:
# (1500, 2000)
# (1500, 2000, 3)

# %%
def plot(img, title, color = True):
    # plt.figure(figsize=(10,10))
    plt.style.use("seaborn-v0_8-white")
    plt.figure(figsize=(8,5))
    plt.title(title)
    if color:
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    else:
        plt.imshow(img, cmap="gray")
    plt.show()

def plot_pair(img1, img2):
    # plt.figure(figsize=(10,10))
    plt.style.use("seaborn-v0_8-white")
    plt.subplot(1,2,1)
    plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
    plt.subplot(1,2,2)
    plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
    plt.show()

def plot_channels(img):
    # plt.figure(figsize=(10,10))
    plt.style.use("seaborn-v0_8-white")
    plt.subplot(1,3,1)
    plt.imshow(img[:,:,2], cmap="gray")
    plt.subplot(1,3,2)
    plt.imshow(img[:,:,1], cmap="gray")
    plt.subplot(1,3,3)
    plt.imshow(img[:,:,0], cmap="gray")
    plt.show()

# plots mask with green overlay
def plot_overlay(img, mask):
    plt.style.use("seaborn-v0_8-white")
    color_mask = np.stack([mask, mask, mask], axis=2)
    color_mask[:, :, 0][mask == 255] = 0
    color_mask[:, :, 2][mask == 255] = 0

    plt.figure(figsize=(6, 6))
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.imshow(color_mask, alpha=0.2)
    plt.show()

# %%
# plt.style.use("seaborn-v0_8-white")
plot(gray, "Grayscale Image")
plot(color, "Color Image")

# %%
plot_channels(color)

# %%
plt.style.use("seaborn-v0_8-whitegrid")
plt.figure(figsize=(8,5))

plt.hist(gray.ravel(), 256, [0, 256], alpha=0.7)
plt.title("Grayscale Image Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Count")
plt.show()

# %%
plt.style.use("seaborn-v0_8-whitegrid")
plt.figure(figsize=(8,5))

plt.hist(color[:,:,0].ravel(), 256, [0, 256], alpha=0.3, color="blue")
plt.hist(color[:,:,1].ravel(), 256, [0, 256], alpha=0.3, color="green")
plt.hist(color[:,:,2].ravel(), 256, [0, 256], alpha=0.3, color="red")
plt.title("Color Image Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Count")
plt.legend(["Blue Channel", "Green Channel", "Red Channel"])
plt.show()
