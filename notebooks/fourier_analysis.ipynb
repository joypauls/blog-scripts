# %%
import numpy as np
import matplotlib.pyplot as plt


# Function to compute the Fourier series approximation of a square wave
def square_wave_fourier_series(x, n):
    sum = np.zeros_like(x)
    for k in range(1, n+1):
        n = 2 * k - 1  # Only odd harmonics
        sum += (1 / n) * np.sin(n * x)
    sum = (4 / np.pi) * sum
    return sum

# Define the domain
x = np.linspace(-np.pi, np.pi, 1000)

# Original square wave function
def square_wave(x):
    return np.sign(np.sin(x))

# Number of Fourier series terms
n = 5  # Change N to see the effect of more terms

# Compute the Fourier series approximation
f_approx = square_wave_fourier_series(x, n)


plt.style.use("seaborn-v0_8-whitegrid")
plt.figure(figsize=(10, 6))
plt.plot(x, square_wave(x), label="Square Wave", linewidth=3)
plt.plot(x, f_approx, label=f"Fourier Series Approximation (n={n})")
plt.title("Fourier Series Approximation of a Square Wave")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
# plt.grid()
plt.show()

# %%
# from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib inline 

x = np.linspace(-np.pi, np.pi, 1000)

def square_wave(x):
    return np.sign(np.sin(x))

# n = 5 
# f_approx = square_wave_fourier_series(x, n)


plt.style.use("seaborn-v0_8-whitegrid")
# plt.figure(figsize=(10, 6))
# figsize=(8, 6)
fig, ax = plt.subplots(figsize=(10, 6))
# line, = ax.plot([], [])

def animate(i):
    ax.clear()
    ax.plot(x, square_wave(x), label="Square Wave", linewidth=3)
    ax.plot(x, square_wave_fourier_series(x, i+1), label=f"Fourier Series Approximation (n={i+1})")
    ax.set_title(f'3D Surface Frame {i+1}')
    ax.set_ylim(-1.5, 1.5)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')

ani = FuncAnimation(fig, animate, frames=20, interval=100)
ani.save("animation.gif", fps=3)
# plt.show()

# %%
n = 5
x = np.linspace(-np.pi, np.pi, 1000)

plt.style.use("seaborn-v0_8-whitegrid")
plt.figure(figsize=(10, 6))
for k in range(1, n + 1):
    n = 2 * k - 1  # Only odd harmonics
    sinusoid = (1 / n) * np.sin(n * x)
    plt.plot(x, sinusoid, label=f"Fourier Series Term {k} (n={n})")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
# plt.grid()
plt.show()
